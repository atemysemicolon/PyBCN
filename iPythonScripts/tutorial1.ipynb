# %% [markdown]
# ####Read an Image

# %%
# %matplotlib inline
from skimage import io,data,color
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('wheel.jpg')
io.imshow(img)
print "Image Dimensions are : ",img.shape
# Out:
# Image Dimensions are :  (400, 400, 3)

# %% [markdown]
# ####Lets play around with it a bit

# %%
blaR = img[:,:,0]
io.imshow(blaR)

# %%
blaG = img[:,:,1]
io.imshow(blaG)

# %%
blaB = img[:,:,2]
io.imshow(blaB)

# %%
bla_gray = (blaB+blaR+blaG) /3
io.imshow(bla_gray)

# %% [markdown]
# ####Simple operations

# %%
mask = blaR> 128;
img[mask] = 255
io.imshow(img)
